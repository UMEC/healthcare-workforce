# %% [markdown]
# # Example of processing user interface changes into Pandas changes

# %% [markdown]
# This notebook explores how a JSON file returned from the User Interface, representing its state could be used to make changes to the panda dataframes that are used as the primary input into the optimizer model.
#
# At the time of writing it was clear that the UI would be unable to generate test data to build this capability within the three weeks of the project, so we have assumed that the output files from the UI will look similar to those that were passed to it i.e. they will be in a hierarchical JSON format.
#
# For simplicity, the code below focuses on a single, but reasonably complex, state change to give the reader an idea as to how the pattern could be extended to the rest of the tool.  Clearly only state that can be changed in the end user interface needs to be handled by programs like this one.  It should be possible, therefore, to extend this mechanism as the user interface becomes more comprehensive.

# %%
import workforce_pandas as wfpd
import numpy as np
import math
wfpd.sheets
# Out:
# ['pop_chronic_trend',
#  'pop_chronic_prev',
#  'chron_care_freq',
#  'geo_area_list',
#  'service_characteristics',
#  'pop_acute_need',
#  'frontsheet',
#  'population',
#  'provider_supply',
#  'pop_prev_need',
#  'provider_list',
#  'encounter_detail',
#  'metadata',
#  'overhead_work',
#  'encounter_types',
#  'index']

# %% [markdown]
# As the return data is quite large, it is more convenient to play with it as a file.  It is recommended that a JSON response is captured from the main data requests APIs (provider_profile, geo_profile) and then modified in an online JSON editor to add, change and remove information.  This will provide a good test file.
#
# In this example we are going to look at provider/type to service mapping and understand what changes (if any) have been made in the user interface.
#
# The instruction below loads the JSON file as a Pyton data dictionary for manipulation.

# %%
import json

with open('../data/my_output2.json') as json_data:
    my_dict = json.load(json_data)

# %% [markdown]
# The format of the resulting dictionary is shown in the cell below:

# %%
my_dict
# Out:
# {'request': {'request_type': 'provider_profile'},
#  'response': {'Phys': {'provider_type': 'Physician',
#    'services:': [{'Counseling': [{'Diet/Physical Activity Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Anticipatory Guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'BRCA risk assessment and genetic counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Breast Cancer Preventive Medications': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Breast Feeding Interventions': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Condition Consultation': {'min_f2f_time': 10,
#         'max_f2f_time': 15,
#         'score': '0.50'}},
#       {'Folic Acid Supplementation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Psychotherapy': {'min_f2f_time': 50,
#         'max_f2f_time': 50,
#         'score': ' '}},
#       {'Tobacco Use Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Visit wrap-up/care planning': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': '0.50'}}]},
#     {'Education': [{'Asthma action plan': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Control: Weight; Hypertension; Hyperlipidemia; Smoking': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}},
#       {'Diabetes Self Management Education/Support': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': '0.50'}},
#       {'Dietary/Physical Activity Guidance': {'min_f2f_time': 10,
#         'max_f2f_time': 10,
#         'score': '0.50'}},
#       {'Exercise & COPD Management': {'min_f2f_time': 15,
#         'max_f2f_time': 15,
#         'score': '0.50'}},
#       {'Inhaler use guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Medical Nutrition Therapy (MNT)': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': '0.50'}}]},
#     {'Immunization': [{'DTaP': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': '0.50'}},
#       {'Hep A\xa0': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Hep B': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Hib': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'HPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'HZV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Influenza': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'IPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Meningococcal': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': '0.50'}},
#       {'MMR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'PCV12': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'PCV13': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Polio': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Rotavirus': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Td/Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'VAR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': '0.50'}}]},
#     {'Lab': [{'Anemia Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}},
#       {'Bacteriuria Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Cervical Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Chlamydia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Dyslipidemia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Gonorrhea Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Hepatitis B Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Hepititis C Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'HIV Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}},
#       {'Lab': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': '0.50'}},
#       {'Lead Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}},
#       {'Newborn Bilirubin': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': '0.50'}},
#       {'Newborn Blood': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': '0.50'}},
#       {'Orders': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': '0.50'}},
#       {'Results Consultation': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Results Consultation: CHD Risk Assessment; A1c; Microalbuminuria': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'STI Screening': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': '0.50'}},
#       {'Syphillis Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'TB* Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}}]},
#     {'Measurements': [{'BMI': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': '0.50'}},
#       {'BP': {'min_f2f_time': 1, 'max_f2f_time': 3, 'score': '0.50'}},
#       {'head circumference': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'length/height & weight': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Temp': {'min_f2f_time': 1, 'max_f2f_time': 2, 'score': '0.50'}},
#       {'Weight': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': '0.50'}}]},
#     {'Oral Health': [{'Fluoride Supplementation': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Fluoride Varnish': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Identify Dental Home': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}}]},
#     {'Patient History': [{'Data Collection': {'min_f2f_time': 2,
#         'max_f2f_time': 3,
#         'score': '0.50'}},
#       {'Interval history/Consultation': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': '0.50'}},
#       {'Patient History': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}}]},
#     {'Pharmacological Treatment/Mgmt': [{'Medication Consultation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Orders/scripts': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}}]},
#     {'Physical Exam': [{'Foot Exam': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': '0.50'}},
#       {'Physical Exam': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Problem Oriented Physical': {'min_f2f_time': 2,
#         'max_f2f_time': 10,
#         'score': '0.50'}}]},
#     {'Physical Screening': [{'Abdominal aortic aneurysm screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Breast Cancer Screening': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': '0.50'}},
#       {'Colorectal Cancer Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Diabetes Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Lung Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Obesity Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': '0.50'}},
#       {'Osteoporosis Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}}]},
#     {'Sensory Screening': [{'Hearing Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}},
#       {'Vision Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': '0.50'}}]}],
#    'supply': {'Beaver County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Box Elder County': {'provider_num': 12,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Cache County': {'provider_num': 14,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Carbon County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Daggett County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Davis County': {'provider_num': 46,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Duchesne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Emery County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Garfield County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Grand County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Iron County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Juab County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Kane County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Millard County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Morgan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Piute County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Rich County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Salt Lake County': {'provider_num': 165,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'San Juan County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Sanpete County': {'provider_num': 8,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Sevier County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Summit County': {'provider_num': 10,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Tooele County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Uintah County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Utah County': {'provider_num': 80,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Wasatch County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Washington County': {'provider_num': 18,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Wayne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Weber County': {'provider_num': 41,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Bear River MCD': {'provider_num': 31,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Central MCD': {'provider_num': 33,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Mountainland MCD': {'provider_num': 96,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Southeast MCD': {'provider_num': 23,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 40,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 17,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 262,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 502,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 177958,
#      'provider_wage_trend': 0.02}}},
#   'PA': {'provider_type': 'Physicial Assistant',
#    'services:': [{'Behavioral Health Screenings': [{'Alcohol Misuse Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Autism Spectrum Disorder Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Depression Screening': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Child Developmental Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Child Developmental Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Intimate partner violence screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Maternal Depression Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Post Partum Depression Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Psychosocial/Behavioral Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Tobacco/Alcohol/Drug Use': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}}]},
#     {'Counseling': [{'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.8}},
#       {'Breast Cancer Preventive Medications': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Breast Feeding Interventions': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Condition Consultation': {'min_f2f_time': 10,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Folic Acid Supplementation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Tobacco Use Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Visit wrap-up/care planning': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Education': [{'Asthma action plan': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Control: Weight; Hypertension; Hyperlipidemia; Smoking': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Diabetes Self Management Education/Support': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}},
#       {'Dietary/Physical Activity Guidance': {'min_f2f_time': 10,
#         'max_f2f_time': 10,
#         'score': 0.5}},
#       {'Exercise & COPD Management': {'min_f2f_time': 15,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Inhaler use guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Medical Nutrition Therapy (MNT)': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}}]},
#     {'Immunization': [{'DTaP': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Hep A\xa0': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hep B': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hib': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HZV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Influenza': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'IPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Meningococcal': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'MMR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV12': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV13': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Polio': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Rotavirus': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Td/Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'VAR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}}]},
#     {'Lab': [{'Anemia Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Bacteriuria Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Cervical Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Chlamydia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Dyslipidemia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Gonorrhea Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Hepatitis B Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Hepititis C Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'HIV Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Lab': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': 0.5}},
#       {'Lead Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Newborn Bilirubin': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Newborn Blood': {'min_f2f_time': 0, 'max_f2f_time': 0, 'score': 0.5}},
#       {'Orders': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Results Consultation': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Results Consultation: CHD Risk Assessment; A1c; Microalbuminuria': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'STI Screening': {'min_f2f_time': 0, 'max_f2f_time': 0, 'score': 0.5}},
#       {'Syphillis Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'TB* Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Measurements': [{'BMI': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'BP': {'min_f2f_time': 1, 'max_f2f_time': 3, 'score': 0.5}},
#       {'head circumference': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'length/height & weight': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Temp': {'min_f2f_time': 1, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Weight': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}}]},
#     {'Oral Health': [{'Fluoride Supplementation': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Fluoride Varnish': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Identify Dental Home': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Patient History': [{'Data Collection': {'min_f2f_time': 2,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Interval history/Consultation': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Patient History': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Pharmacological Treatment/Mgmt': [{'Medication Consultation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Orders/scripts': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}}]},
#     {'Physical Exam': [{'Foot Exam': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Physical Exam': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': 0.5}},
#       {'Problem Oriented Physical': {'min_f2f_time': 2,
#         'max_f2f_time': 10,
#         'score': 0.5}}]},
#     {'Physical Screening': [{'Abdominal aortic aneurysm screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Breast Cancer Screening': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Colorectal Cancer Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Diabetes Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Lung Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Obesity Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Osteoporosis Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Sensory Screening': [{'Hearing Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Vision Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]}],
#    'supply': {'Beaver County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Box Elder County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Cache County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Carbon County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Daggett County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Davis County': {'provider_num': 19,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Duchesne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Emery County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Garfield County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Grand County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Iron County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Juab County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Kane County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Millard County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Morgan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Piute County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Rich County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Salt Lake County': {'provider_num': 72,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'San Juan County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Sanpete County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Sevier County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Summit County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Tooele County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Uintah County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Utah County': {'provider_num': 32,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Wasatch County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Washington County': {'provider_num': 8,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Wayne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Weber County': {'provider_num': 19,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Bear River MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Central MCD': {'provider_num': 30,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Mountainland MCD': {'provider_num': 43,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Southeast MCD': {'provider_num': 22,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 29,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 120,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 274,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 105690,
#      'provider_wage_trend': 0.02}}},
#   'NP': {'provider_type': 'Nurse Practitioner',
#    'services:': [{'Behavioral Health Screenings': [{'Alcohol Misuse Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Autism Spectrum Disorder Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Depression Screening': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Child Developmental Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Child Developmental Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Intimate partner violence screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Maternal Depression Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Psychosocial/Behavioral Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Tobacco/Alcohol/Drug Use': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}}]},
#     {'Counseling': [{'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Anticipatory Guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Breast Cancer Preventive Medications': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Condition Consultation': {'min_f2f_time': 10,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Folic Acid Supplementation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Tobacco Use Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Visit wrap-up/care planning': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Education': [{'Asthma action plan': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Control: Weight; Hypertension; Hyperlipidemia; Smoking': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Diabetes Self Management Education/Support': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}},
#       {'Dietary/Physical Activity Guidance': {'min_f2f_time': 10,
#         'max_f2f_time': 10,
#         'score': 0.5}},
#       {'Exercise & COPD Management': {'min_f2f_time': 15,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Inhaler use guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Medical Nutrition Therapy (MNT)': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}}]},
#     {'Immunization': [{'DTaP': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Hep A\xa0': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hep B': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hib': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HZV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Influenza': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'IPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Meningococcal': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'MMR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV12': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV13': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Polio': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Rotavirus': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Td/Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'VAR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}}]},
#     {'Lab': [{'Anemia Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Cervical Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Chlamydia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Dyslipidemia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Gonorrhea Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Hepititis C Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'HIV Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Lab': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': 0.5}},
#       {'Lead Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Newborn Bilirubin': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Newborn Blood': {'min_f2f_time': 0, 'max_f2f_time': 0, 'score': 0.5}},
#       {'Orders': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Results Consultation': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Results Consultation: CHD Risk Assessment; A1c; Microalbuminuria': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'STI Screening': {'min_f2f_time': 0, 'max_f2f_time': 0, 'score': 0.5}},
#       {'TB* Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Measurements': [{'BMI': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'BP': {'min_f2f_time': 1, 'max_f2f_time': 3, 'score': 0.5}},
#       {'head circumference': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'length/height & weight': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Temp': {'min_f2f_time': 1, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Weight': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}}]},
#     {'Oral Health': [{'Fluoride Supplementation': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Fluoride Varnish': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Identify Dental Home': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Patient History': [{'Data Collection': {'min_f2f_time': 2,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Interval history/Consultation': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Patient History': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Pharmacological Treatment/Mgmt': [{'Medication Consultation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Orders/scripts': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}}]},
#     {'Physical Exam': [{'Foot Exam': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Physical Exam': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': 0.5}},
#       {'Problem Oriented Physical': {'min_f2f_time': 2,
#         'max_f2f_time': 10,
#         'score': 0.5}}]},
#     {'Physical Screening': [{'Abdominal aortic aneurysm screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Breast Cancer Screening': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Colorectal Cancer Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Diabetes Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Lung Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Obesity Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Osteoporosis Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Sensory Screening': [{'Hearing Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Vision Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]}],
#    'supply': {'Beaver County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Box Elder County': {'provider_num': 9,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Cache County': {'provider_num': 14,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Carbon County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Daggett County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Davis County': {'provider_num': 19,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Duchesne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Emery County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Garfield County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Grand County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Iron County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Juab County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Kane County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Millard County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Morgan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Piute County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Rich County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Salt Lake County': {'provider_num': 305,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'San Juan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Sanpete County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Sevier County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Summit County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Tooele County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Uintah County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Utah County': {'provider_num': 68,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Wasatch County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Washington County': {'provider_num': 27,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Wayne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Weber County': {'provider_num': 47,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Bear River MCD': {'provider_num': 28,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Central MCD': {'provider_num': 30,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Mountainland MCD': {'provider_num': 80,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Southeast MCD': {'provider_num': 20,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 48,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 381,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 602,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 95994,
#      'provider_wage_trend': 0.02}}},
#   'RN': {'provider_type': 'Registered Nurse',
#    'services:': [{'Behavioral Health Screenings': [{'Alcohol Misuse Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Autism Spectrum Disorder Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Depression Screening': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Child Developmental Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Child Developmental Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Intimate partner violence screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Maternal Depression Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Psychosocial/Behavioral Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Tobacco/Alcohol/Drug Use': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}}]},
#     {'Counseling': [{'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Anticipatory Guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Breast Cancer Preventive Medications': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Condition Consultation': {'min_f2f_time': 10,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Folic Acid Supplementation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Tobacco Use Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Visit wrap-up/care planning': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Education': [{'Asthma action plan': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Control: Weight; Hypertension; Hyperlipidemia; Smoking': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Diabetes Self Management Education/Support': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}},
#       {'Dietary/Physical Activity Guidance': {'min_f2f_time': 10,
#         'max_f2f_time': 10,
#         'score': 0.5}},
#       {'Exercise & COPD Management': {'min_f2f_time': 15,
#         'max_f2f_time': 15,
#         'score': 0.5}},
#       {'Inhaler use guidance': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Medical Nutrition Therapy (MNT)': {'min_f2f_time': 30,
#         'max_f2f_time': 30,
#         'score': 0.5}}]},
#     {'Immunization': [{'DTaP': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Hep A\xa0': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hep B': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Hib': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'HZV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Influenza': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'IPV': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Meningococcal': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'MMR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV12': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'PCV13': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Polio': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Rotavirus': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Td/Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'Tdap': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}},
#       {'VAR': {'min_f2f_time': 3, 'max_f2f_time': 3, 'score': 0.5}}]},
#     {'Lab': [{'Anemia Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Cervical Cancer Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Chlamydia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Dyslipidemia Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Gonorrhea Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Hepititis C Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'HIV Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Lab': {'min_f2f_time': 5, 'max_f2f_time': 5, 'score': 0.5}},
#       {'Lead Screening': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Newborn Bilirubin': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Newborn Blood': {'min_f2f_time': 0, 'max_f2f_time': 0, 'score': 0.5}},
#       {'Orders': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Results Consultation': {'min_f2f_time': 2,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Results Consultation: CHD Risk Assessment; A1c; Microalbuminuria': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'TB* Screening': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Measurements': [{'BMI': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'BP': {'min_f2f_time': 1, 'max_f2f_time': 3, 'score': 0.5}},
#       {'head circumference': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'length/height & weight': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Temp': {'min_f2f_time': 1, 'max_f2f_time': 2, 'score': 0.5}},
#       {'Weight': {'min_f2f_time': 2, 'max_f2f_time': 2, 'score': 0.5}}]},
#     {'Oral Health': [{'Fluoride Supplementation': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Fluoride Varnish': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Identify Dental Home': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]},
#     {'Patient History': [{'Data Collection': {'min_f2f_time': 2,
#         'max_f2f_time': 3,
#         'score': 0.5}},
#       {'Interval history/Consultation': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Patient History': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}}]},
#     {'Pharmacological Treatment/Mgmt': [{'Medication Consultation': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
# ...
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 62000,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 86,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 62000,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 20,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 62000,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 727,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 62000,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 1093,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 62000,
#      'provider_wage_trend': 0.02}}},
#   'CMHC': {'provider_type': 'Certified Mental Health Counselor',
#    'services:': [{'Behavioral Health Screenings': [{'Alcohol Misuse Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Autism Spectrum Disorder Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Depression Screening': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Child Developmental Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Child Developmental Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Intimate partner violence screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Maternal Depression Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Psychosocial/Behavioral Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Tobacco/Alcohol/Drug Use': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}}]},
#     {'Counseling': [{'Diet/Physical Activity Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Alcohol Misuse Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'BRCA risk assessment and genetic counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'CBT': {'min_f2f_time': 50, 'max_f2f_time': 50, 'score': 0.5}},
#       {'Obesity Counseling': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Psychotherapy': {'min_f2f_time': 50,
#         'max_f2f_time': 50,
#         'score': 0.5}},
#       {'Sexually Transmitted Infections Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Skin Cancer Behavioral Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Tobacco Use Prevention and Counseling ': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]}],
#    'supply': {'Beaver County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Box Elder County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Cache County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Carbon County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Daggett County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Davis County': {'provider_num': 23,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Duchesne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Emery County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Garfield County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Grand County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Iron County': {'provider_num': 11,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Juab County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Kane County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Millard County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Morgan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Piute County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Rich County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Salt Lake County': {'provider_num': 151,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'San Juan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Sanpete County': {'provider_num': 7,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Sevier County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Summit County': {'provider_num': 9,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Tooele County': {'provider_num': 6,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Uintah County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Utah County': {'provider_num': 46,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Wasatch County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Washington County': {'provider_num': 22,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Wayne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Weber County': {'provider_num': 16,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Bear River MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Central MCD': {'provider_num': 32,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Mountainland MCD': {'provider_num': 60,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Southeast MCD': {'provider_num': 20,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 48,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 201,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 391,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 52500,
#      'provider_wage_trend': 0.02}}},
#   'MFT': {'provider_type': 'Marriage and Family Therapists',
#    'services:': [{'Behavioral Health Screenings': [{'Alcohol Misuse Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Autism Spectrum Disorder Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Depression Screening': {'min_f2f_time': 4,
#         'max_f2f_time': 4,
#         'score': 0.5}},
#       {'Child Developmental Screening': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Child Developmental Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Intimate partner violence screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Maternal Depression Screening': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Psychosocial/Behavioral Surveillance': {'min_f2f_time': 2,
#         'max_f2f_time': 2,
#         'score': 0.5}},
#       {'Tobacco/Alcohol/Drug Use': {'min_f2f_time': 3,
#         'max_f2f_time': 3,
#         'score': 0.5}}]},
#     {'Counseling': [{'Diet/Physical Activity Counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Advanced Care Planning': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'Alcohol Misuse Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'BRCA risk assessment and genetic counseling': {'min_f2f_time': 5,
#         'max_f2f_time': 5,
#         'score': 0.5}},
#       {'CBT': {'min_f2f_time': 50, 'max_f2f_time': 50, 'score': 0.5}},
#       {'Obesity Counseling': {'min_f2f_time': 0,
#         'max_f2f_time': 0,
#         'score': 0.5}},
#       {'Psychotherapy': {'min_f2f_time': 50,
#         'max_f2f_time': 50,
#         'score': 0.5}},
#       {'Sexually Transmitted Infections Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Skin Cancer Behavioral Counseling': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}},
#       {'Tobacco Use Prevention and Counseling ': {'min_f2f_time': 1,
#         'max_f2f_time': 1,
#         'score': 0.5}}]}],
#    'supply': {'Beaver County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Box Elder County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Cache County': {'provider_num': 14,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Carbon County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Daggett County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Davis County': {'provider_num': 11,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Duchesne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Emery County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Garfield County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Grand County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Iron County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Juab County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Kane County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Millard County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Morgan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Piute County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Rich County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Salt Lake County': {'provider_num': 51,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'San Juan County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Sanpete County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Sevier County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Summit County': {'provider_num': 8,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Tooele County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Uintah County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Utah County': {'provider_num': 45,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Wasatch County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Washington County': {'provider_num': 16,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Wayne County': {'provider_num': 5,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Weber County': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Bear River MCD': {'provider_num': 24,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Central MCD': {'provider_num': 30,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Mountainland MCD': {'provider_num': 58,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Southeast MCD': {'provider_num': 20,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Southwest MCD': {'provider_num': 36,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Uintah Basin MCD': {'provider_num': 15,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'Wasatch MCD': {'provider_num': 87,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02},
#     'State of Utah': {'provider_num': 270,
#      'provider_growth_trend': 0.01,
#      'provider_mean_wage': 55590,
#      'provider_wage_trend': 0.02}}}}}

# %% [markdown]
# To navigate the JSON structure, it will be useful to have a list of the provider types abbreviations; these can be extracted quickly from the provider list dataframe.

# %%
provider_list = wfpd.dataframes["provider_list"]["provider_abbr"]
list(provider_list)
# Out:
# ['Phys',
#  'PA',
#  'NP',
#  'RN',
#  'PharmD',
#  'MA',
#  'Educ',
#  'Psych',
#  'LCSW',
#  'CMHC',
#  'MFT']

# %% [markdown]
# The data we are going to compare against is stored in the service characteristics dataframe, so we give it an easy to rememebr variable name (and no, I can't remember why I called it total wage - probably an early morning cut and paste without thinking!)

# %%
total_wage = wfpd.dataframes["service_characteristics"]
total_wage
# Out:
#                       svc_category  \
# 0     Behavioral Health Screenings
# 1     Behavioral Health Screenings
# 2     Behavioral Health Screenings
# 3     Behavioral Health Screenings
# 4     Behavioral Health Screenings
# 5     Behavioral Health Screenings
# 6     Behavioral Health Screenings
# 7     Behavioral Health Screenings
# 8     Behavioral Health Screenings
# 9     Behavioral Health Screenings
# 10                      Counseling
# 11                      Counseling
# 12                      Counseling
# 13                      Counseling
# 14                      Counseling
# 15                      Counseling
# 16                      Counseling
# 17                      Counseling
# 18  Pharmacological Treatment/Mgmt
# 19                      Counseling
# 20                      Counseling
# 21                      Counseling
# 22                      Counseling
# 23                      Counseling
# 24                      Counseling
# 25                      Counseling
# 26                      Counseling
# 27                       Education
# 28                       Education
# 29                       Education
# ..                             ...
# 66                             Lab
# 67                             Lab
# 68                             Lab
# 69                             Lab
# 70                    Measurements
# 71                    Measurements
# 72                    Measurements
# 73                    Measurements
# 74                    Measurements
# 75                    Measurements
# 76                     Oral Health
# 77                     Oral Health
# 78                     Oral Health
# 79                 Patient History
# 80                 Patient History
# 81                 Patient History
# 82  Pharmacological Treatment/Mgmt
# 83  Pharmacological Treatment/Mgmt
# 84                   Physical Exam
# 85                   Physical Exam
# 86                   Physical Exam
# 87              Physical Screening
# 88              Physical Screening
# 89              Physical Screening
# 90              Physical Screening
# 91              Physical Screening
# 92              Physical Screening
# 93              Physical Screening
# 94               Sensory Screening
# 95               Sensory Screening
#
#                                              svc_desc  min_f2f_time  \
# 0                            Alcohol Misuse Screening           2.0
# 1                  Autism Spectrum Disorder Screening           5.0
# 2                                Depression Screening           4.0
# 3                       Child Developmental Screening           5.0
# 4                    Child Developmental Surveillance           2.0
# 5                 Intimate partner violence screening           2.0
# 6                       Maternal Depression Screening           2.0
# 7                    Post Partum Depression Screening           5.0
# 8                Psychosocial/Behavioral Surveillance           2.0
# 9                            Tobacco/Alcohol/Drug Use           3.0
# 10                  Diet/Physical Activity Counseling           5.0
# 11                             Advanced Care Planning           5.0
# 12                          Alcohol Misuse Counseling           1.0
# 13                              Anticipatory Guidance           5.0
# 14        BRCA risk assessment and genetic counseling           5.0
# 15               Breast Cancer Preventive Medications           5.0
# 16                       Breast Feeding Interventions           5.0
# 17                                                CBT          50.0
# 18                          Condition Rx consultation          10.0
# 19                         Folic Acid Supplementation           5.0
# 20                                 Obesity Counseling           0.0
# 21                                      Psychotherapy          50.0
# 22         Sexually Transmitted Infections Counseling           1.0
# 23                  Skin Cancer Behavioral Counseling           1.0
# 24                             Tobacco Use Counseling           5.0
# 25             Tobacco Use Prevention and Counseling            1.0
# 26                        Visit wrap-up/care planning           2.0
# 27                                 Asthma action plan           5.0
# 28  Control: Weight; Hypertension; Hyperlipidemia;...           2.0
# 29         Diabetes Self Management Education/Support          30.0
# ..                                                ...           ...
# 66  Results Consultation: CHD Risk Assessment; A1c...           5.0
# 67                                      STI Screening           0.0
# 68                                Syphillis Screening           5.0
# 69                                      TB* Screening           1.0
# 70                                                BMI           0.0
# 71                                                 BP           1.0
# 72                                 head circumference           1.0
# 73                             length/height & weight           1.0
# 74                                               Temp           1.0
# 75                                             Weight           2.0
# 76                           Fluoride Supplementation           1.0
# 77                                   Fluoride Varnish           1.0
# 78                               Identify Dental Home           1.0
# 79                                    Data Collection           2.0
# 80                      Interval history/Consultation           4.0
# 81                                    Patient History           5.0
# 82                            Medication Consultation           5.0
# 83                                     Orders/scripts           2.0
# 84                                          Foot Exam           2.0
# 85                                      Physical Exam           5.0
# 86                          Problem Oriented Physical           2.0
# 87                Abdominal aortic aneurysm screening           5.0
# 88                            Breast Cancer Screening           0.0
# 89                        Colorectal Cancer Screening           1.0
# 90                                 Diabetes Screening           5.0
# 91                              Lung Cancer Screening           5.0
# 92                                  Obesity Screening           5.0
# 93                             Osteoporosis Screening           1.0
# 94                                  Hearing Screening           1.0
# 95                                   Vision Screening           1.0
#
#     max_f2f_time  Phys   PA   NP   RN  PharmD   MA  Educ  Psych  LCSW  CMHC  \
# 0            2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 1            5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 2            4.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 3            5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 4            2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 5            2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 6            2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 7            5.0   0.5  0.5  NaN  NaN     NaN  NaN   NaN    0.5   NaN   NaN
# 8            2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 9            3.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 10           5.0   0.5  NaN  NaN  NaN     NaN  NaN   0.5    NaN   0.5   0.5
# 11           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 12           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 13           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 14           5.0   0.5  NaN  NaN  NaN     NaN  NaN   NaN    NaN   0.5   0.5
# 15           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 16           5.0   0.5  0.5  NaN  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 17          50.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 18          15.0   0.5  0.5  0.5  0.5     0.5  NaN   NaN    NaN   NaN   NaN
# 19           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 20           0.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 21          50.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 22           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 23           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 24           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    0.5   NaN   NaN
# 25           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 26           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 27           5.0   0.5  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# 28           2.0   0.5  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# 29          30.0   0.5  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# ..           ...   ...  ...  ...  ...     ...  ...   ...    ...   ...   ...
# 66           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 67           0.0   0.5  0.5  0.5  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 68           5.0   0.5  0.5  NaN  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 69           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 70           0.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 71           3.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 72           1.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 73           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 74           2.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 75           2.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 76           1.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 77           1.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 78           1.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 79           3.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 80           4.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 81           5.0   0.5  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 82           5.0   0.5  0.5  0.5  0.5     0.5  NaN   0.5    NaN   NaN   NaN
# 83           2.0   0.5  0.5  0.5  NaN     0.5  NaN   NaN    NaN   NaN   NaN
# 84           2.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 85           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 86          10.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 87           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 88           0.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 89           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 90           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 91           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 92           5.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 93           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 94           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 95           1.0   0.5  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
#
#     MFT
# 0   0.5
# 1   0.5
# 2   0.5
# 3   0.5
# 4   0.5
# 5   0.5
# 6   0.5
# 7   NaN
# 8   0.5
# 9   0.5
# 10  0.5
# 11  0.5
# 12  0.5
# 13  NaN
# 14  0.5
# 15  NaN
# 16  NaN
# 17  0.5
# 18  NaN
# 19  NaN
# 20  0.5
# 21  0.5
# 22  0.5
# 23  0.5
# 24  NaN
# 25  0.5
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# ..  ...
# 66  NaN
# 67  NaN
# 68  NaN
# 69  NaN
# 70  NaN
# 71  NaN
# 72  NaN
# 73  NaN
# 74  NaN
# 75  NaN
# 76  NaN
# 77  NaN
# 78  NaN
# 79  NaN
# 80  NaN
# 81  NaN
# 82  NaN
# 83  NaN
# 84  NaN
# 85  NaN
# 86  NaN
# 87  NaN
# 88  NaN
# 89  NaN
# 90  NaN
# 91  NaN
# 92  NaN
# 93  NaN
# 94  NaN
# 95  NaN
#
# [96 rows x 15 columns]

# %% [markdown]
# The routine below cycles through the the existing service characteristics dataframe one row at a time.  For each column that corresponds to a profession type, it reads the existing value for suitability.
#
# As the JSON only contains the information with valid entries and a number of arrays (i.e. NaNs are not stored), the parsing is not necessarily straightforward.  The nested loops below basically parse the JSON tree using the values from the base dataframe, detecting dead ends in the JSON data structure and then moving on.
#
# This routine successfully identifies:
# * When suitability for a provider_type has been removed (i.e there is no entry in the JSON, but there is in the dataframe)
# * When suitability for a provider_type has been changed (i.e. when the entries in the JSON and dataframe don't match)
# * When suitability for a provider_type has been created (i.e. when the JSON contains an entry, but the dataframe contains NaN)
#
# It will _not_ automatically identify completely new services (i.e. rows) that were not present in the imported dataframes.  It is suggested that a separate routine should identify new services created in the UI; this could run _before_ this routine and would could update the services rows in the dataframes.  This would then enable this service to pick up the new relationships.  A similar routine could be used for providers too...
#
# Clearly this routine, as written, only considers the suitability figures.  The same pattern should be able to be deployed for the other columns in the sheet (and indeed for the rest of the UI scope).  As they say in the best text books - this is left as an exercise for the reader.

# %%
not_defined_in_json = "not defined in json"

# %%
for row_index, row in total_wage.iterrows():
    #print (row['min_f2f_time'], row['max_f2f_time'])
    #print ("==========================================================")
    #print (str(row['svc_category'] +"/"+ str(row['svc_desc'])))
    for column in total_wage[provider_list]:
        #score = my_dict.get('response').get(column).get('services:')[0].get(row['svc_category'])[0].get(row['svc_desc'].get('score'))
        new_value = not_defined_in_json
        old_value = row[column]
        #print (type(old_value),old_value)
        #print (column + " old value : " + str(old_value))
        category_size = int(len(my_dict.get('response').get(column).get('services:')))
        #print ("Category: " + str(category_size))
        for n in range(category_size):
            in_json1 = my_dict.get('response').get(column).get('services:')[n].get(row['svc_category'])
            if in_json1 != None :
                description_size = int(len(my_dict.get('response').get(column).get('services:')[n].get(row['svc_category'])))
                #print ("Svc desc: " + str(description_size
                for m in range(description_size):
                    in_json2 = my_dict.get('response').get(column).get('services:')[n].get(row['svc_category'])[m]
                    if in_json2 != None :
                        #print(in_json2)
                        in_json3 = my_dict.get('response').get(column).get('services:')[n].get(row['svc_category'])[m].get(row['svc_desc'])
                        if in_json3 != None :
                            new_value = my_dict.get('response').get(column).get('services:')[n].get(row['svc_category'])[m].get(row['svc_desc']).get('score')
                            string = "Comparison: " + column + " : " + str(old_value) + " -> " + str(new_value)
        if (new_value != old_value):
            if not ((math.isnan(old_value)) and (new_value == not_defined_in_json)):
                if new_value == "not defined in json":
                    total_wage.loc[row_index,column] = np.NaN
                else:
                    total_wage.loc[row_index,column] = new_value

# %% [markdown]
# The total_wage is a variable representation of the dataframe, so updating the total_wage dataframe has updated the wfpd.dataframe that is used as a parameter for the optimization calculator.

# %%
wfpd.dataframes["service_characteristics"]
# Out:
#                       svc_category  \
# 0     Behavioral Health Screenings
# 1     Behavioral Health Screenings
# 2     Behavioral Health Screenings
# 3     Behavioral Health Screenings
# 4     Behavioral Health Screenings
# 5     Behavioral Health Screenings
# 6     Behavioral Health Screenings
# 7     Behavioral Health Screenings
# 8     Behavioral Health Screenings
# 9     Behavioral Health Screenings
# 10                      Counseling
# 11                      Counseling
# 12                      Counseling
# 13                      Counseling
# 14                      Counseling
# 15                      Counseling
# 16                      Counseling
# 17                      Counseling
# 18  Pharmacological Treatment/Mgmt
# 19                      Counseling
# 20                      Counseling
# 21                      Counseling
# 22                      Counseling
# 23                      Counseling
# 24                      Counseling
# 25                      Counseling
# 26                      Counseling
# 27                       Education
# 28                       Education
# 29                       Education
# ..                             ...
# 66                             Lab
# 67                             Lab
# 68                             Lab
# 69                             Lab
# 70                    Measurements
# 71                    Measurements
# 72                    Measurements
# 73                    Measurements
# 74                    Measurements
# 75                    Measurements
# 76                     Oral Health
# 77                     Oral Health
# 78                     Oral Health
# 79                 Patient History
# 80                 Patient History
# 81                 Patient History
# 82  Pharmacological Treatment/Mgmt
# 83  Pharmacological Treatment/Mgmt
# 84                   Physical Exam
# 85                   Physical Exam
# 86                   Physical Exam
# 87              Physical Screening
# 88              Physical Screening
# 89              Physical Screening
# 90              Physical Screening
# 91              Physical Screening
# 92              Physical Screening
# 93              Physical Screening
# 94               Sensory Screening
# 95               Sensory Screening
#
#                                              svc_desc  min_f2f_time  \
# 0                            Alcohol Misuse Screening           2.0
# 1                  Autism Spectrum Disorder Screening           5.0
# 2                                Depression Screening           4.0
# 3                       Child Developmental Screening           5.0
# 4                    Child Developmental Surveillance           2.0
# 5                 Intimate partner violence screening           2.0
# 6                       Maternal Depression Screening           2.0
# 7                    Post Partum Depression Screening           5.0
# 8                Psychosocial/Behavioral Surveillance           2.0
# 9                            Tobacco/Alcohol/Drug Use           3.0
# 10                  Diet/Physical Activity Counseling           5.0
# 11                             Advanced Care Planning           5.0
# 12                          Alcohol Misuse Counseling           1.0
# 13                              Anticipatory Guidance           5.0
# 14        BRCA risk assessment and genetic counseling           5.0
# 15               Breast Cancer Preventive Medications           5.0
# 16                       Breast Feeding Interventions           5.0
# 17                                                CBT          50.0
# 18                          Condition Rx consultation          10.0
# 19                         Folic Acid Supplementation           5.0
# 20                                 Obesity Counseling           0.0
# 21                                      Psychotherapy          50.0
# 22         Sexually Transmitted Infections Counseling           1.0
# 23                  Skin Cancer Behavioral Counseling           1.0
# 24                             Tobacco Use Counseling           5.0
# 25             Tobacco Use Prevention and Counseling            1.0
# 26                        Visit wrap-up/care planning           2.0
# 27                                 Asthma action plan           5.0
# 28  Control: Weight; Hypertension; Hyperlipidemia;...           2.0
# 29         Diabetes Self Management Education/Support          30.0
# ..                                                ...           ...
# 66  Results Consultation: CHD Risk Assessment; A1c...           5.0
# 67                                      STI Screening           0.0
# 68                                Syphillis Screening           5.0
# 69                                      TB* Screening           1.0
# 70                                                BMI           0.0
# 71                                                 BP           1.0
# 72                                 head circumference           1.0
# 73                             length/height & weight           1.0
# 74                                               Temp           1.0
# 75                                             Weight           2.0
# 76                           Fluoride Supplementation           1.0
# 77                                   Fluoride Varnish           1.0
# 78                               Identify Dental Home           1.0
# 79                                    Data Collection           2.0
# 80                      Interval history/Consultation           4.0
# 81                                    Patient History           5.0
# 82                            Medication Consultation           5.0
# 83                                     Orders/scripts           2.0
# 84                                          Foot Exam           2.0
# 85                                      Physical Exam           5.0
# 86                          Problem Oriented Physical           2.0
# 87                Abdominal aortic aneurysm screening           5.0
# 88                            Breast Cancer Screening           0.0
# 89                        Colorectal Cancer Screening           1.0
# 90                                 Diabetes Screening           5.0
# 91                              Lung Cancer Screening           5.0
# 92                                  Obesity Screening           5.0
# 93                             Osteoporosis Screening           1.0
# 94                                  Hearing Screening           1.0
# 95                                   Vision Screening           1.0
#
#     max_f2f_time  Phys   PA   NP   RN  PharmD   MA  Educ  Psych  LCSW  CMHC  \
# 0            2.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 1            5.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 2            4.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 3            5.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 4            2.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 5            2.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 6            2.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 7            5.0   NaN  0.5  NaN  NaN     NaN  NaN   NaN    0.5   NaN   NaN
# 8            2.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 9            3.0   NaN  0.5  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 10           5.0  0.50  NaN  NaN  NaN     NaN  NaN   0.5    NaN   0.5   0.5
# 11           5.0  0.50  0.8  0.5  0.5     NaN  NaN   NaN    0.5   0.5   0.5
# 12           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 13           5.0  0.50  NaN  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 14           5.0  0.50  NaN  NaN  NaN     NaN  NaN   NaN    NaN   0.5   0.5
# 15           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 16           5.0  0.50  0.5  NaN  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 17          50.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 18          15.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 19           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 20           0.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 21          50.0        NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 22           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 23           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 24           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    0.5   NaN   NaN
# 25           1.0   NaN  NaN  NaN  NaN     NaN  NaN   NaN    0.5   0.5   0.5
# 26           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 27           5.0  0.50  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# 28           2.0  0.50  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# 29          30.0  0.50  0.5  0.5  0.5     NaN  NaN   0.5    NaN   NaN   NaN
# ..           ...   ...  ...  ...  ...     ...  ...   ...    ...   ...   ...
# 66           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 67           0.0  0.50  0.5  0.5  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 68           5.0  0.50  0.5  NaN  NaN     NaN  NaN   NaN    NaN   NaN   NaN
# 69           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 70           0.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 71           3.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 72           1.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 73           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 74           2.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 75           2.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 76           1.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 77           1.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 78           1.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 79           3.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 80           4.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 81           5.0  0.50  0.5  0.5  0.5     NaN  0.5   NaN    NaN   NaN   NaN
# 82           5.0  0.50  0.5  0.5  0.5     0.5  NaN   0.5    NaN   NaN   NaN
# 83           2.0  0.50  0.5  0.5  NaN     0.5  NaN   NaN    NaN   NaN   NaN
# 84           2.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 85           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 86          10.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 87           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 88           0.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 89           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 90           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 91           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 92           5.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 93           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 94           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
# 95           1.0  0.50  0.5  0.5  0.5     NaN  NaN   NaN    NaN   NaN   NaN
#
#     MFT
# 0   0.5
# 1   0.5
# 2   0.5
# 3   0.5
# 4   0.5
# 5   0.5
# 6   0.5
# 7   NaN
# 8   0.5
# 9   0.5
# 10  0.5
# 11  0.5
# 12  0.5
# 13  NaN
# 14  0.5
# 15  NaN
# 16  NaN
# 17  0.5
# 18  NaN
# 19  NaN
# 20  0.5
# 21  0.5
# 22  0.5
# 23  0.5
# 24  NaN
# 25  0.5
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN
# ..  ...
# 66  NaN
# 67  NaN
# 68  NaN
# 69  NaN
# 70  NaN
# 71  NaN
# 72  NaN
# 73  NaN
# 74  NaN
# 75  NaN
# 76  NaN
# 77  NaN
# 78  NaN
# 79  NaN
# 80  NaN
# 81  NaN
# 82  NaN
# 83  NaN
# 84  NaN
# 85  NaN
# 86  NaN
# 87  NaN
# 88  NaN
# 89  NaN
# 90  NaN
# 91  NaN
# 92  NaN
# 93  NaN
# 94  NaN
# 95  NaN
#
# [96 rows x 15 columns]
