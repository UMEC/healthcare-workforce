# %% [markdown]
# Import external matrices into a pandas data frame

# %%
import pandas as pd
svc_prov_mtx_lto = pd.read_csv("/Users/hopkira/Documents/Utah Model/serv_prov_mtx_lto.csv")
svc_prov_mtx_max = pd.read_csv("/Users/hopkira/Documents/Utah Model/serv_prov_mtx_max.csv")
svc_timings = pd.read_csv("/Users/hopkira/Documents/Utah Model/service_timings.csv")

# %% [markdown]
# Remove the first line after header which contains no data

# %%
svc_prov_mtx_lto=svc_prov_mtx_lto.drop(svc_prov_mtx_lto.index[0])
svc_prov_mtx_max=svc_prov_mtx_max.drop(svc_prov_mtx_max.index[0])
svc_timings=svc_timings.drop(svc_timings.index[0])
print (svc_prov_mtx_lto.head(2))
print (svc_prov_mtx_lto.head(2))
print (svc_timings.head(2))
# Out:
#                        Category      Routine Service Care Category  \
# 2  Behavioral Health Screenings  Well-Child Visits-A    Preventive
# 3  Behavioral Health Screenings  Well-Child Visits-A    Preventive
#
#                           Service Physician   PA   NP   RN  Psychiatrist  \
# 2     Developmental Screening (1)      0.00  0.0  0.0  0.0          0.25
# 3  Developmental Surveillance (5)      0.00  0.0  0.0  0.0          0.25
#
#    LCSW  CHMC   MFT  PharmD  MA  Educator
# 2   0.5   0.6  0.25     NaN NaN       NaN
# 3   0.5   0.6  0.25     NaN NaN       NaN
#                        Category      Routine Service Care Category  \
# 2  Behavioral Health Screenings  Well-Child Visits-A    Preventive
# 3  Behavioral Health Screenings  Well-Child Visits-A    Preventive
#
#                           Service Physician   PA   NP   RN  Psychiatrist  \
# 2     Developmental Screening (1)      0.00  0.0  0.0  0.0          0.25
# ...

# %%
svc_prov_mtx_lto=svc_prov_mtx_lto.set_index(['Care Category', 'Routine Service','Category','Service'])
svc_prov_mtx_max=svc_prov_mtx_max.set_index(['Care Category', 'Routine Service','Category','Service'])
svc_timings=svc_timings.set_index(['Care Category', 'Routine Service','Category','Service'])

# %% [markdown]
# Extract LTO for a service/provider combination

# %%
svc_prov_mtx_lto.loc[("Acute","Chest pain","Measurements","BP"),"PA"]
# Out:
# /Users/hopkira/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# Care Category  Routine Service  Category      Service
# Acute          Chest pain       Measurements  BP         0.0
# Name: PA, dtype: float64

# %%
svc_prov_mtx_lto
# Out:
#                                                                                                                                          Physician  \
# Care Category Routine Service                                    Category                       Service
# Preventive    Well-Child Visits-A                                Behavioral Health Screenings   Developmental Screening (1)                   0.00
#                                                                                                 Developmental Surveillance (5)                0.00
#                                                                                                 Psychosocial/Behavioral Surveillance (6)      0.00
#                                                                                                 Maternal Depression Screening (4)             0.00
# ...

# %%
svc_prov_mtx_max
# Out:
#                                                                                                                                          Physician  \
# Care Category Routine Service                                    Category                       Service
# Preventive    Well-Child Visits-A                                Behavioral Health Screenings   Developmental Screening (1)                    0.3
#                                                                                                 Developmental Surveillance (5)                 0.3
#                                                                                                 Psychosocial/Behavioral Surveillance (6)       0.3
#                                                                                                 Maternal Depression Screening (4)              0.3
# ...

# %%
svc_timings
# Out:
#                                                                                                                                           Frequency  \
# Care Category Routine Service                                    Category                       Service
# Preventive    Well-Child Visits-A                                Behavioral Health Screenings   Developmental Screening (1)                     1.0
#                                                                                                 Developmental Surveillance (5)                  5.0
#                                                                                                 Psychosocial/Behavioral Surveillance (6)        6.0
#                                                                                                 Maternal Depression Screening (4)               4.0
# ...

# %%
svc_prov_mtx_lto.loc[("Acute","Chest pain","Measurements","BP"),"NP"]
# Out:
# /Users/hopkira/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# Care Category  Routine Service  Category      Service
# Acute          Chest pain       Measurements  BP         0.0
# Name: NP, dtype: float64

# %%
svc_prov_mtx_max.loc[("Acute","Chest pain","Measurements","BP"),"NP"]
# Out:
# /Users/hopkira/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# Care Category  Routine Service  Category      Service
# Acute          Chest pain       Measurements  BP         0.8
# Name: NP, dtype: float64

# %%
svc_timings.loc[("Acute","Chest pain","Measurements","BP"),"F2F"]
# Out:
# /Users/hopkira/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1472: PerformanceWarning: indexing past lexsort depth may impact performance.
#   return self._getitem_tuple(key)
# Care Category  Routine Service  Category      Service
# Acute          Chest pain       Measurements  BP         2.0
# Name: F2F, dtype: float64
